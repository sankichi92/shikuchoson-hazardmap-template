# %%
import pandas as pd

# %%
df = pd.read_excel("../data_original/hachioji_hinanjo.xlsx", "投入データ", index_col=0, na_values=[9])
# Out:
# /Users/takahiro-miyoshi/Repositories/hachioji-hazardmap/.venv/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df.head()
# Out:
#              削除                        名称  名称カナ                  住所  \
# ID (v2.0)
# 1320100001  NaN  浅川河川敷（長沼橋付近～市立上壱分方小学校付近）   NaN  東京都八王子市元本郷町3-500-4
# 1320100002  NaN                     富士森公園   NaN        東京都八王子市台町2-2
# 1320100003  NaN                      陵南公園   NaN     東京都八王子市長房町、東浅川町
# 1320100004  NaN                      小宮公園   NaN    東京都八王子市大谷町、暁町二丁目
# 1320100005  NaN                     工学院大学   NaN    東京都八王子市中野町2665-1
#
#                    緯度          経度  電話番号  自治体名    コード  避難場所  ...  高潮  地震  津波  \
# ID (v2.0)                                                   ...
# 1320100001  35.667613  139.314149   NaN  八王子市  13201  True  ... NaN   1 NaN
# 1320100002  35.650935  139.322890   NaN  八王子市  13201  True  ... NaN   1 NaN
# 1320100003  35.649184  139.289186   NaN  八王子市  13201  True  ... NaN   1 NaN
# 1320100004  35.672756  139.340966   NaN  八王子市  13201  True  ... NaN   1 NaN
# 1320100005  35.686712  139.318743   NaN  八王子市  13201  True  ... NaN   1 NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 1320100001 to 1320100152
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   削除            2 non-null      object
#  1   名称            152 non-null    object
#  2   名称カナ          0 non-null      float64
#  3   住所            152 non-null    object
#  4   緯度            152 non-null    float64
#  5   経度            152 non-null    float64
#  6   電話番号          0 non-null      float64
#  7   自治体名          152 non-null    object
#  8   コード           152 non-null    int64
#  9   避難場所          152 non-null    bool
#  10  避難所           152 non-null    bool
#  11  施設種別呼称        0 non-null      float64
#  12  洪水            152 non-null    int64
#  13  崖崩れ、土石流及び地滑り  152 non-null    int64
#  14  高潮            2 non-null      float64
#  15  地震            152 non-null    int64
#  16  津波            2 non-null      float64
# ...

# %%
df = df[df['削除'] != True]
df.drop(['自治体名', 'コード'], axis=1, inplace=True)
df.dropna(axis=1, how='all', inplace=True)
df.replace({0: False, 1: True}, inplace=True)

# %%
df.head()
# Out:
#                                   名称                  住所         緯度  \
# ID (v2.0)
# 1320100001  浅川河川敷（長沼橋付近～市立上壱分方小学校付近）  東京都八王子市元本郷町3-500-4  35.667613
# 1320100002                     富士森公園        東京都八王子市台町2-2  35.650935
# 1320100003                      陵南公園     東京都八王子市長房町、東浅川町  35.649184
# 1320100004                      小宮公園    東京都八王子市大谷町、暁町二丁目  35.672756
# 1320100005                     工学院大学    東京都八王子市中野町2665-1  35.686712
#
#                     経度  避難場所    避難所     洪水  崖崩れ、土石流及び地滑り    地震   内水氾濫      備考
# ID (v2.0)
# 1320100001  139.314149  True  False  False         False  True  False  広域避難場所
# 1320100002  139.322890  True  False  False         False  True  False  広域避難場所
# 1320100003  139.289186  True  False  False         False  True  False  広域避難場所
# 1320100004  139.340966  True  False  False         False  True  False  広域避難場所
# 1320100005  139.318743  True  False  False         False  True  False  広域避難場所

# %%
df[['緯度', '経度']].describe()
# Out:
#                緯度          経度
# count  150.000000  150.000000
# mean    35.651287  139.329944
# std      0.024604    0.042899
# min     35.608239  139.210475
# 25%     35.629744  139.301584
# 50%     35.650522  139.322735
# 75%     35.670799  139.361188
# max     35.705542  139.426089
